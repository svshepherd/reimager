# %% [markdown]
# # setup prefixes

# %%
from PIL import Image
from PIL.ExifTags import TAGS, GPSTAGS
import requests
import os
import datetime

def extract_date_taken(file):
    """this looks like it's doing a better job than my original method 
    for extracting date_taken, independent of subsequent edits."""
    image = Image.open(file)

    # Extract EXIF data
    exif_data = image._getexif()
    if exif_data is not None:
        for tag, value in exif_data.items():
            tag_name = TAGS.get(tag, tag)
            if tag_name == "DateTimeOriginal":
                # Convert the date format from string to datetime
                date_time_obj = datetime.datetime.strptime(value, '%Y:%m:%d %H:%M:%S')
                return date_time_obj
    return None

### specifically, this didn't work well:
#
#[(k,v) for k,v in ExifTags.TAGS.items() if 'time' in v.lower()]

### example results:
# [(306, 'DateTime'),
#  (33434, 'ExposureTime'),
#  (34858, 'TimeZoneOffset'),
#  (34859, 'SelfTimerMode'),
#  (36867, 'DateTimeOriginal'),
#  (36868, 'DateTimeDigitized'),
#  (36880, 'OffsetTime'),
#  (36881, 'OffsetTimeOriginal'),
#  (36882, 'OffsetTimeDigitized'),
#  (37520, 'SubsecTime'),
#  (37521, 'SubsecTimeOriginal'),
#  (37522, 'SubsecTimeDigitized'),
#  (42082, 'CompositeImageExposureTimes'),
#  (50971, 'PreviewDateTime')]

### evidently I may also need to think about  (36881, 'OffsetTimeOriginal') and (36882, 'OffsetTimeDigitized'),

# %%
import os
from PIL import Image, ExifTags

PATHNAME = r'F:\extended_desktop\ims'
#PATHNAME = r'F:\extended_desktop\ims\_incoming'
#PATHNAME = r'F:\extended_desktop\_incoming\10430121'

files = [f for f in os.listdir(PATHNAME) if os.path.isfile(os.path.join(PATHNAME, f))] 
files
# Out:
# ['20230628 hymenopts (1).JPG',
#  '20230630 (10).JPG',
#  '20230630 (11).JPG',
#  '20230630 (13).JPG',
#  '20230630 (17).JPG',
#  '20230630 (19).JPG',
#  '20230630 (20).JPG',
#  '20230630 (21).jpg',
#  '20230630 (25).JPG',
#  '20230630 (28).JPG',
#  '20230630 (42).JPG',
#  '20230630 (46).JPG',
#  '20230630 (49).JPG',
#  '20230630 (53).JPG',
#  '20230630 (55).JPG',
#  '20230630 (58).JPG',
#  '20230702 (23).JPG',
#  '20230702 (29).JPG',
#  '20230702 (30).JPG',
#  '20230702 (34).JPG',
#  '20230702 (37).JPG',
#  '20230702 (38).JPG',
#  '20230702 (40).JPG',
#  '20230702 (42).JPG',
#  '20230702 (43).JPG',
#  '20230702 (45).JPG',
#  '20230702 (49).JPG',
#  '20230702 (51).JPG',
#  '20230702 (55).JPG',
#  '20230702 (64).JPG',
#  '20230703 (10).JPG',
#  '20230703 (100).JPG',
#  '20230703 (101).JPG',
#  '20230703 (11).JPG',
#  '20230703 (12).JPG',
#  '20230703 (13).JPG',
#  '20230703 (14).JPG',
#  '20230703 (15).JPG',
#  '20230703 (16).JPG',
#  '20230703 (22).JPG',
#  '20230703 (23).jpg',
#  '20230703 (24).JPG',
#  '20230722_021653297.NIGHT.jpg',
#  '20230722_021705913.NIGHT.jpg',
#  '20230722_030621438.NIGHT.jpg',
#  '20230722_030627916.NIGHT.jpg',
#  '20230722_152327171.jpg',
#  '20230722_153524936.jpg',
#  '20230722_153532406.jpg',
#  '20230722_153542712.jpg',
#  '20230722_193135008.jpg',
#  '20230722_202236928.jpg',
#  '20230722_202312263.jpg',
#  'dragonfly breathing.psd',
#  '_incoming.lnk',
#  '_workshop.lnk']

# %%
for file in files:
    try:
        day = extract_date_taken(os.path.join(PATHNAME, file))
        day_prefix = f"{day:%Y%m%d}"
        if file.endswith('.ARW'):
            continue
        elif file.startswith(day_prefix):
            print(file, "===== ALREADY GOOD!!")
            continue
        else:
            newname = day_prefix+" "+file
            os.rename(os.path.join(PATHNAME, file), os.path.join(PATHNAME, newname))
            print(file, "---->", newname, "SUCCESSFUL")
    except Exception as e:
        print(file, "----X", e)   
    # if file[4]+file[7]=='--':
    #     newname = file[:4]+file[5:7]+file[8:]
    #     os.rename(os.path.join(PATHNAME, file), os.path.join(PATHNAME, newname))
    #     print(file, "---->", newname, "SUCCESSFUL")
    # elif file.startswith('PXL_'):
    #     newname = file[4:]
    #     os.rename(os.path.join(PATHNAME, file), os.path.join(PATHNAME, newname))
    #     print(file, "---->", newname, "SUCCESSFUL")
    # elif file.startswith('D')|file.startswith('P')|file.startswith('W'):
    #     try: 
    #         img = Image.open(os.path.join(PATHNAME, file))
    #         img_exif = img.getexif()
    #         ## [(k,v) for k,v in ExifTags.TAGS.items() if 'date' in v.lower()] ### 36867, 36868, 306
    #         ### evidently I also need to think about OffsetTime from GMT
    #         if 36867 in img_exif.keys():
    #             imname_pref = ''.join(img_exif[36867][:10].split(':'))+' '
    #         elif 36868 in img_exif.keys():
    #             imname_pref = ''.join(img_exif[36868][:10].split(':'))+' '
    #         else:
    #             imname_pref = ''.join(img_exif[306][:10].split(':'))+' '
    #         img.close()
    #         if imname_pref == file[:9]:
    #             print(file, "----=", file)
    #             try:
    #                 fileraw = file[9:].replace('.JPG','.ARW')
    #                 os.rename(os.path.join(PATHNAME, fileraw), os.path.join(PATHNAME, imname_pref + fileraw))
    #                 print(fileraw, "---->", imname_pref + fileraw, "SUCCESSFUL")
    #             except Exception as e:
    #                 print(e)
    #         else:
    #             print(file, "---->", imname_pref + file)
    #             os.rename(os.path.join(PATHNAME, file), os.path.join(PATHNAME, imname_pref + file))
    #             print(file, "---->", imname_pref + file, "SUCCESSFUL")
    #             try:
    #                 fileraw = file.replace('.JPG','.ARW')
    #                 os.rename(os.path.join(PATHNAME, fileraw), os.path.join(PATHNAME, imname_pref + fileraw))
    #                 print(fileraw, "---->", imname_pref + fileraw, "SUCCESSFUL")
    #             except Exception as e:
    #                 print(e + '.')
    #     except Exception as e:
    #         print(file, "----X", e)
    # else: 
    #     print('  already processed or unanticipated name format: ', file)
# Out:
#   Cell In[3], line 7
#     elif:
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # purge awr files where no jpg is retained

# %%
import os
from PIL import Image, ExifTags

## goal here is to remove any .arw raw files where i didn't think the .jpg was worth saving

## confirm:
PATHNAME = r'F:\extended_desktop\_incoming\10430121'

files = [f for f in os.listdir(PATHNAME) if os.path.isfile(os.path.join(PATHNAME, f))] 

raw_files = [f for f in files if f.lower().endswith('.arw')]
jpg_files = [f for f in files if f.lower().endswith('.jpg')]
jpg_stem = [f[:-4] for f in jpg_files]
raw_to_lose = [f for f in raw_files if f[:-4] not in jpg_stem]

display(f"Focused folder is {PATHNAME}")
len(raw_to_lose), len(raw_files)
# Out:
# 'Focused folder is F:\\extended_desktop\\_incoming\\10430121'
# (79, 106)

# %%
for f in raw_to_lose:
    print(f"removing {f}")
    os.remove( os.path.join(PATHNAME, f) )
# Out:
# removing DSC00729.ARW
# removing DSC00730.ARW
# removing DSC00731.ARW
# removing DSC00732.ARW
# removing DSC00734.ARW
# removing DSC00735.ARW
# removing DSC00736.ARW
# removing DSC00737.ARW
# removing DSC00739.ARW
# removing DSC00740.ARW
# removing DSC00742.ARW
# removing DSC00743.ARW
# removing DSC00744.ARW
# removing DSC00745.ARW
# removing DSC00746.ARW
# removing DSC00747.ARW
# removing DSC00748.ARW
# removing DSC00749.ARW
# removing DSC00750.ARW
# removing DSC00751.ARW
# removing DSC00752.ARW
# removing DSC00754.ARW
# removing DSC00755.ARW
# removing DSC00756.ARW
# removing DSC00757.ARW
# removing DSC00759.ARW
# removing DSC00760.ARW
# removing DSC00761.ARW
# removing DSC00763.ARW
# removing DSC00764.ARW
# removing DSC00765.ARW
# removing DSC00766.ARW
# removing DSC00768.ARW
# removing DSC00769.ARW
# removing DSC00772.ARW
# removing DSC00773.ARW
# removing DSC00774.ARW
# removing DSC00775.ARW
# removing DSC00776.ARW
# removing DSC00777.ARW
# removing DSC00778.ARW
# removing DSC00779.ARW
# removing DSC00780.ARW
# removing DSC00781.ARW
# removing DSC00782.ARW
# removing DSC00783.ARW
# removing DSC00785.ARW
# removing DSC00786.ARW
# removing DSC00788.ARW
# removing DSC00789.ARW
# removing DSC00790.ARW
# removing DSC00791.ARW
# removing DSC00793.ARW
# removing DSC00794.ARW
# removing DSC00797.ARW
# removing DSC00798.ARW
# removing DSC00799.ARW
# removing DSC00800.ARW
# removing DSC00801.ARW
# removing DSC00803.ARW
# removing DSC00804.ARW
# removing DSC00805.ARW
# removing DSC00806.ARW
# removing DSC00807.ARW
# removing DSC00809.ARW
# removing DSC00810.ARW
# removing DSC00812.ARW
# removing DSC00814.ARW
# removing DSC00815.ARW
# removing DSC00816.ARW
# removing DSC00817.ARW
# removing DSC00818.ARW
# removing DSC00819.ARW
# removing DSC00820.ARW
# removing DSC00821.ARW
# removing DSC00822.ARW
# removing DSC00832.ARW
# removing DSC00833.ARW
# removing DSC00834.ARW
