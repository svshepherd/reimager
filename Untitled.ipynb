# %%
import renamer
#renamer.extract_date_taken(r'..\..\vis\_workdir\_on the move\jeremiah\20240812 DSC03750.JPG')

# %%
import os
os.chdir('../../vis')

# %%
renamer.main()
# Out:
# 20240409 PXL_20240409_195247750.jpg ===== ALREADY GOOD!!
# 20240824 DSC04027.psd ----X 'PsdImageFile' object has no attribute '_getexif'
# 20241109 Aurel Schmidt (2006) Super Natural.jpg ===== ALREADY GOOD!!
# 20241109 DSCF0334.JPG ===== ALREADY GOOD!!
# 20241109 DSCF0335.JPG ===== ALREADY GOOD!!
# 20241109 louis wain.jpg ===== ALREADY GOOD!!
# 20241109 max explores.JPG ===== ALREADY GOOD!!
# 20241109 PXL_20241109_192443120.MP.jpg ===== ALREADY GOOD!!
# 20241109 PXL_20241109_192725327.jpg ===== ALREADY GOOD!!
# 20241109 PXL_20241109_192728574.jpg ===== ALREADY GOOD!!
# 20241109 PXL_20241109_192731039.MP.jpg ===== ALREADY GOOD!!
# 20241109 PXL_20241109_192737995.jpg ===== ALREADY GOOD!!
# 20241109 PXL_20241109_193217066.MP.jpg ===== ALREADY GOOD!!
# 20241109 PXL_20241110_004213290.MP.jpg ===== ALREADY GOOD!!
# 20241110 PXL_20241110_171728104.MP.jpg ===== ALREADY GOOD!!
# 20241124 PXL_20241124_225538433.jpg ===== ALREADY GOOD!!
# ...
